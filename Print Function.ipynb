# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-16 09-50-28.png")

# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-16 09-52-50.png")

# %% [markdown]
# ### Sol1
# #### print(*range(1,int(input()) +1 ),sep = "")

# %% [markdown]
# ### Sol2
# #### n = int(input())
# #### for i in range(1,n+1):
# ####    print(i,end="")

# %% [markdown]
# The * is used to unpack a iterable(list, string,tuple etc) in python
