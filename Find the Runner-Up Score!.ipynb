# %%
from IPython.display import Image
Image("//home//saket//Pictures//Screenshot from 2021-03-17 20-23-26.png")

# %%
n = int(input())
arr = map(int, input().split())
arr_new = list(set(arr))
arr_new.sort()
print(arr_new[-2])
# Out:
# 6
# 45 89 65 78 45 21 14
# 78
